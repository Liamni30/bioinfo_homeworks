# %% [markdown]
# ### Часть 1 — Множественное выравнивание

# %% [markdown]
# Для множественного выравнивания был выбран белок гемоглобин субъединица альфа из-за его консерватиности (хорошо подходит для филогенетического анализа)
#
# Выбранные виды и их accession в базе UniProt:
#
# | Вид | Название | UniProt accession |
# |-----|----------|-------------------|
# | *Homo sapiens* | Человек | P69905 |
# | *Mus musculus* | Мышь домашняя | P01942 |
# | *Bos taurus* | Корова домашняя | P01966 |
# | *Danio rerio* | Данио-рерио (рыба) | Q90487 |

# %% [markdown]
# ### 1) Проведение выравнивания
#
# Проведем множественное выравнивание с помощью инструмента Clustal Omega (https://www.ebi.ac.uk/jdispatcher/msa/clustalo)
#
# Скрин полученного выравнивания:

# %% [markdown]
# ![chrome_b3BnQ874dT.png](attachment:10da84fc-a527-4eb3-b493-34c4066b30a6.png)

# %% [markdown]
# Рассмотрим поближе:

# %% [markdown]
# ![chrome_Bdebn8rOqg.png](attachment:96a1fab3-fc42-421a-93ac-1b9b00fea074.png)

# %% [markdown]
# ![chrome_Bqs6Hgwa80.png](attachment:819c7511-4423-4840-9390-c8ee61dc99b5.png)

# %% [markdown]
# Видим как консервативные позиции, сохранившиеся у всех четырёх видов, так и вариабельные участки

# %% [markdown]
# ### 2)Построение дерева

# %% [markdown]
# По результатам выравнивания был получен Newick-формат филогенетического дерева, и далее была выполнена визуализация дерева с помощью сервиса iTOL (https://itol.embl.de)

# %% [markdown]
# ![chrome_sdWRrRwhX7.png](attachment:3a22c348-1b8b-458e-b482-e9c6da0553fa.png)

# %% [markdown]
# ### Выводы
# Анализ полученного дерева:
#
# -  Последовательность *Danio rerio* (рыба) отделилась первой и образует самую длинную внешнюю ветвь, что отражает наибольшее эволюционное расстояние между рыбами и млекопитающими
#
# - Все три вида млекопитающих (*Homo sapiens*, *Mus musculus*, *Bos taurus*) сгруппировались в один кластер, что отражает их общее происхождение.
#
# - Внутри кластера млекопитающих *Homo sapiens* и *Bos taurus* оказались ближе друг к другу, чем к *Mus musculus*
#
# Итого, построенное филогенетическое дерево соответствует ожидаемым эволюционным отношениям между видами. Таким образом выравнивание может использоваться для анализа эволюционных связей

# %% [markdown]
# ### Часть 2 - MEGA и коронавирус

# %% [markdown]
# ### 2.1. Множественное выравнивание и дерево

# %% [markdown]
# Cделаем множественное выравнивание последовательностей короновируса внутри программы мега:

# %% [markdown]
# ![MEGA_64_wAFKywcjJi.png](attachment:47f0887b-b342-4f40-b15e-0c28315f48fd.png)

# %% [markdown]
# Построим дерево внутри программы мега:

# %% [markdown]
# ![tree.png](attachment:07d7f57d-4ff3-485f-8894-ee6df979a2bb.png)

# %% [markdown]
# **Вывод по пункту 2.1:**
#
# На филогенетическом дереве образцы разделились на две основные группы.
#
# Верхняя группа объединяет около 20 последовательностей и имеет внутреннюю структуру с несколькими  подгруппами. Скорее всего данные образцы принадлежат одному варианту вируса с небольшими внутренними различиями.
#
# Нижняя группа последовательностей (11302, 10966, 10989, 10981, 10922, 10950, 10888, 10949, 10969, 11309) образует длинные ветви. Это указывает на большее генетическое разнообразие этих образцов и возможную принадлежность к другим вариантам вируса.

# %% [markdown]
# ### 2.2 Добавление штаммов из других стран

# %% [markdown]
# Выберем Австралию, Бразилию и Ливию (в Северной Африке)

# %% [markdown]
# Множественное выравнивание с добавлением их:

# %% [markdown]
# ![MEGA_64_VgUomez8GS.png](attachment:c6ddd2cb-654e-4931-b797-4bd29c74fd64.png)

# %% [markdown]
# Дерево:

# %% [markdown]
# ![tree.png](attachment:3d5b5c55-ed55-49f7-97f9-a1b1171dd449.png)

# %% [markdown]
# **Вывод по пункту 2.2:**
#
# Три добавленные зарубежные последовательности расположились внутри верхнего российского кластера, а не образовали отдельных ветвей. Значит зарубежные последовательности генетически близки к части российских образцов, несмотря на географическую удалённость.
#
# Это позволяет сделать вывод об особенностях рапространения ковида в 2021 году - одновременно на разных континентах присутвовал вирус с схожими последовательностями s-белка

# %% [markdown]
# ### Часть 3 — BLAST

# %% [markdown]
# ### 3.1 Неизвестный белок

# %% [markdown]
# 1. Найдем что за белок кодирует данная последовательность:

# %% [markdown]
# ![chrome_C3gc7XEJru.png](attachment:254ea09e-ee44-45ba-a439-05572c0260a0.png)

# %% [markdown]
# Видим, что это Chain B, Rhodopsin [Bos taurus]

# %% [markdown]
# 2. Проверим есть ли у человека ортолог данного гена:

# %% [markdown]
# Можно использовать как tblastn(ищет белковый запрос в нуклеотидной базе, переводит нуклеотиды на лету), так и blastp (ищет белок по белковой базе). Но tblastn имеет смысл использовать только если в белковой базе нет, а так blastp будет быстрее и чувствительнее. Т.к RefSeq содержит белковые последовательности человека **используем blastp.**
#
# В качествн базы данных выберем RefSeq proteins (refseq_protein), т.к это база проверенных аннотированных белков.

# %% [markdown]
# ![chrome_afT30OWzPk.png](attachment:6e546ee6-5ff0-4a8a-8ad0-6ea8596e3afa.png)

# %% [markdown]
# Если используем tblastn получим аналогичный результат:

# %% [markdown]
# ![chrome_EcyhAATPaz.png](attachment:0392a9d2-6847-469e-bd3c-1e3903759fdb.png)

# %% [markdown]
# Итого, ортолог у человека - rhodopsin

# %% [markdown]
# 3. Дефект зрения, связанный с этим белком

# %% [markdown]
# Можем почитать его summary на nr:

# %% [markdown]
# *Summary: The protein encoded by this gene is found in rod cells in
#             the back of the eye and is essential for vision in low-light
#             conditions. The encoded protein binds to 11-cis retinal and is
#             activated when light hits the retinal molecule. Defects in this
#             gene are a cause of congenital stationary night blindness.
#             [provided by RefSeq, Aug 2017].*

# %% [markdown]
# Итого, дефекты в этом гене являются причиной врожденной стационарной ночной слепоты.

# %% [markdown]
# ### 3.2 10 лучших кандидатов на белковую последовательность люциферазы в транскриптоме Photinus pyralis

# %% [markdown]
# Для выполнения этого задания использовались следующие программы:
#
# | Программа | Назначение |
# |---|---|
# | TransDecoder | Поиск открытых рамок считывания и перевод нуклеотидов в белки |
# | makeblastdb | Создание BLAST-базы данных из белковых последовательностей |
# | blastp | Поиск гомологичных белков |
# | seqtk | Извлечение последовательностей из FASTA-файла по списку ID |

# %% [markdown]
# Файл photinus_top10_candidates.fasta содержит 10 белковых последовательностей в формате FASTA и приложен к отчету
